# %% [markdown]
# ## Trajectory preprocessing

# %% [markdown]
# We need to make molecules whole and center them
# http://www.gromacs.org/Documentation/Terminology/Periodic_Boundary_Conditions
# http://manual.gromacs.org/documentation/current/onlinehelp/gmx-trjconv.html

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from myimports import *
display(Markdown(descr))
# Out:
# _ColormakerRegistry()
# # MD simulations of H2A-H2B with 30 bp of DNA, tails truncated
# - AMBER14SB force field
# - 150 mM NaCl
# - box 2nm

# %%
# %%bash  -s "$set_gmx_cmd" "$noappend"
# $1
# #The code below was collapsed to one shell file
# ./5_trj_preprocessing.sh 7_prod sys_md $2
# Out:
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 22: '!Water_and_ions'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for clustering
# Selected 22: '!Water_and_ions'
# Select group for output
# Selected 22: '!Water_and_ions'
# Clustering iteration 4 of 4...
# Clustering iteration 4 of 4...
# Clustering iteration 4 of 4...
# Clustering iteration 4 of 4...
# Note that major changes are planned in future for trjconv, to improve usability and utility.
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# Select group for least squares fit
# Selected 0: 'System'
# Select group for output
# Selected 0: 'System'
#                      :-) GROMACS - gmx trjconv, 2020.1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1
# Executable:   /opt/gromacs/2020.1_nompi/bin/gmx
# Data prefix:  /opt/gromacs/2020.1_nompi
# Working dir:  /home/_shared/_projects/gmx_template
# Command line:
#   gmx trjconv -n GMX_system/index.ndx -f GMX_run/7_prod.xtc -s GMX_run/7_prod.tpr -o tmp/7_prod_1.xtc -pbc whole
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file GMX_run/7_prod.tpr, VERSION 2020.1 (single precision)
# Reading file GMX_run/7_prod.tpr, VERSION 2020.1 (single precision)
# Group     0 (         System) has 86212 elements
# Group     1 (            DNA) has  1908 elements
# Group     2 (             NA) has   116 elements
# Group     3 (             CL) has    73 elements
# Group     4 (        Protein) has  2998 elements
# Group     5 (      Protein-H) has  1463 elements
# Group     6 (        C-alpha) has   186 elements
# Group     7 (       Backbone) has   558 elements
# Group     8 (      MainChain) has   742 elements
# Group     9 (   MainChain+Cb) has   917 elements
# Group    10 (    MainChain+H) has   925 elements
# Group    11 (      SideChain) has  2073 elements
# Group    12 (    SideChain-H) has   721 elements
# Group    13 (    Prot-Masses) has  2998 elements
# Group    14 (    non-Protein) has 83214 elements
# Group    15 (          Water) has 81117 elements
# Group    16 (            SOL) has 81117 elements
# Group    17 (      non-Water) has  5095 elements
# Group    18 (            Ion) has   189 elements
# Group    19 (             NA) has   116 elements
# Group    20 (             CL) has    73 elements
# Group    21 ( Water_and_ions) has 81306 elements
# Group    22 (!Water_and_ions) has  4906 elements
# Group    23 (           a_11) has     1 elements
# Group    24 (         a_1888) has     1 elements
# Group    25 (          a_937) has     1 elements
# Group    26 (          a_968) has     1 elements
# Reading frame       0 time    0.000
# Precision of GMX_run/7_prod.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up tmp/7_prod_1.xtc to tmp/#7_prod_1.xtc.18#
# Last frame          3 time 3000.000
#
#
# GROMACS reminds you: "Uh-oh" (Tinky Winky)
#
#                      :-) GROMACS - gmx trjconv, 2020.1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1
# Executable:   /opt/gromacs/2020.1_nompi/bin/gmx
# Data prefix:  /opt/gromacs/2020.1_nompi
# Working dir:  /home/_shared/_projects/gmx_template
# Command line:
#   gmx trjconv -n GMX_system/index.ndx -f tmp/7_prod_1.xtc -s GMX_run/7_prod.tpr -o tmp/7_prod_2.xtc -pbc cluster
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file GMX_run/7_prod.tpr, VERSION 2020.1 (single precision)
# Reading file GMX_run/7_prod.tpr, VERSION 2020.1 (single precision)
# Group     0 (         System) has 86212 elements
# Group     1 (            DNA) has  1908 elements
# Group     2 (             NA) has   116 elements
# Group     3 (             CL) has    73 elements
# Group     4 (        Protein) has  2998 elements
# Group     5 (      Protein-H) has  1463 elements
# Group     6 (        C-alpha) has   186 elements
# Group     7 (       Backbone) has   558 elements
# Group     8 (      MainChain) has   742 elements
# Group     9 (   MainChain+Cb) has   917 elements
# Group    10 (    MainChain+H) has   925 elements
# Group    11 (      SideChain) has  2073 elements
# Group    12 (    SideChain-H) has   721 elements
# Group    13 (    Prot-Masses) has  2998 elements
# Group    14 (    non-Protein) has 83214 elements
# Group    15 (          Water) has 81117 elements
# Group    16 (            SOL) has 81117 elements
# Group    17 (      non-Water) has  5095 elements
# Group    18 (            Ion) has   189 elements
# Group    19 (             NA) has   116 elements
# Group    20 (             CL) has    73 elements
# Group    21 ( Water_and_ions) has 81306 elements
# Group    22 (!Water_and_ions) has  4906 elements
# Group    23 (           a_11) has     1 elements
# Group    24 (         a_1888) has     1 elements
# Group    25 (          a_937) has     1 elements
# Group    26 (          a_968) has     1 elements
# Select a group: Group     0 (         System) has 86212 elements
# Group     1 (            DNA) has  1908 elements
# Group     2 (             NA) has   116 elements
# Group     3 (             CL) has    73 elements
# Group     4 (        Protein) has  2998 elements
# Group     5 (      Protein-H) has  1463 elements
# Group     6 (        C-alpha) has   186 elements
# Group     7 (       Backbone) has   558 elements
# Group     8 (      MainChain) has   742 elements
# Group     9 (   MainChain+Cb) has   917 elements
# Group    10 (    MainChain+H) has   925 elements
# Group    11 (      SideChain) has  2073 elements
# Group    12 (    SideChain-H) has   721 elements
# Group    13 (    Prot-Masses) has  2998 elements
# Group    14 (    non-Protein) has 83214 elements
# Group    15 (          Water) has 81117 elements
# Group    16 (            SOL) has 81117 elements
# Group    17 (      non-Water) has  5095 elements
# Group    18 (            Ion) has   189 elements
# Group    19 (             NA) has   116 elements
# Group    20 (             CL) has    73 elements
# Group    21 ( Water_and_ions) has 81306 elements
# Group    22 (!Water_and_ions) has  4906 elements
# Group    23 (           a_11) has     1 elements
# Group    24 (         a_1888) has     1 elements
# Group    25 (          a_937) has     1 elements
# Group    26 (          a_968) has     1 elements
# Reading frame       0 time    0.000
# Precision of tmp/7_prod_1.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up tmp/7_prod_2.xtc to tmp/#7_prod_2.xtc.11#
# Last frame          3 time 3000.000
#
#
# GROMACS reminds you: "Dreams seldom materialize on their own." (Dian Fossey)
#
#                      :-) GROMACS - gmx trjconv, 2020.1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1
# Executable:   /opt/gromacs/2020.1_nompi/bin/gmx
# Data prefix:  /opt/gromacs/2020.1_nompi
# Working dir:  /home/_shared/_projects/gmx_template
# Command line:
#   gmx trjconv -f tmp/7_prod_2.xtc -s GMX_system/sys_ref.pdb -o big_data/sys_md.xtc -fit rot+trans
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Group     0 (         System) has  4906 elements
# Group     1 (            DNA) has  1908 elements
# Group     2 (        Protein) has  2998 elements
# Group     3 (      Protein-H) has  1463 elements
# Group     4 (        C-alpha) has   186 elements
# Group     5 (       Backbone) has   558 elements
# Group     6 (      MainChain) has   742 elements
# Group     7 (   MainChain+Cb) has   917 elements
# Group     8 (    MainChain+H) has   925 elements
# Group     9 (      SideChain) has  2073 elements
# Group    10 (    SideChain-H) has   721 elements
# Group    11 (    Prot-Masses) has  2998 elements
# Group    12 (    non-Protein) has  1908 elements
# Select a group: Group     0 (         System) has  4906 elements
# Group     1 (            DNA) has  1908 elements
# Group     2 (        Protein) has  2998 elements
# Group     3 (      Protein-H) has  1463 elements
# Group     4 (        C-alpha) has   186 elements
# Group     5 (       Backbone) has   558 elements
# Group     6 (      MainChain) has   742 elements
# Group     7 (   MainChain+Cb) has   917 elements
# Group     8 (    MainChain+H) has   925 elements
# Group     9 (      SideChain) has  2073 elements
# Group    10 (    SideChain-H) has   721 elements
# Group    11 (    Prot-Masses) has  2998 elements
# Group    12 (    non-Protein) has  1908 elements
# Reading frame       0 time    0.000
# Precision of tmp/7_prod_2.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up big_data/sys_md.xtc to big_data/#sys_md.xtc.7#
# Last frame          3 time 3000.000
#
#
# GROMACS reminds you: "Dr Pauling, how do you have so many good ideas? Well David, I have a lot of ideas and throw away the bad ones." (Linus Pauling)

# %% [markdown]
# ## Old version below is inactive

# %% [markdown]
# %%bash
# mkdir -p tmp
# mkdir -p big_data
# #The group here may need to be adjusted if you have other components except protein, e.g. DNA
# gmx trjconv -n GMX_system/index.ndx -f GMX_run/7_prod.xtc -s GMX_run/7_prod.tpr -o tmp/7_prod_1.xtc -pbc whole << !
# !Water_and_ions
# !

# %% [markdown]
# %%bash --out out
# gmx trjconv -n GMX_system/index.ndx -f tmp/7_prod_1.xtc -s GMX_run/7_prod.tpr -o tmp/7_prod_2.xtc -pbc cluster << !
# !Water_and_ions
# !Water_and_ions
# !

# %% [markdown]
# %%bash
# gmx trjconv  -f tmp/7_prod_2.xtc -s GMX_system/sys_ref.pdb -o big_data/sys_md.xtc -fit rot+trans << !
# System
# System
# !
